# %% [markdown]
# # Groupby for bar charts

# %% [markdown]
# ## Load data

# %%
path = '../../data/EIA/fuel_type_data_california.parquet'

# %%
import pandas as pd
df = pd.read_parquet(path)

df
# Out:
#                           period respondent respondent-name fueltype  \
# 0      2025-04-22 20:00:00-07:00        CAL      California      BAT
# 1      2025-04-22 20:00:00-07:00        CAL      California      COL
# ...                          ...        ...             ...      ...
# 452546 2018-12-31 17:00:00-07:00        CAL      California      WAT
# 452547 2018-12-31 17:00:00-07:00        CAL      California      WND
#
#               type-name  value    value-units
# 0       Battery storage    179  megawatthours
# 1                  Coal    216  megawatthours
# ...                 ...    ...            ...
# 452546            Hydro   2880  megawatthours
# 452547             Wind   2628  megawatthours
#
# [452548 rows x 7 columns]

# %%
df = df.set_index('period').sort_index()
df = df.loc['2024', ['type-name', 'value']]
df.columns = ['technology', 'energy']

df
# Out:
#                           technology  energy
# period
# 2024-01-01 00:00:00-07:00       Wind     243
# 2024-01-01 00:00:00-07:00      Hydro    3541
# ...                              ...     ...
# 2024-12-31 23:00:00-07:00      Hydro    4125
# 2024-12-31 23:00:00-07:00       Wind     476
#
# [70224 rows x 2 columns]

# %% [markdown]
# ## Calculate temporal properties

# %%
#import sys 
#sys.path.append('C:/Users/mmart/Documents/MM Computer files/Programming/LITimeSeries/practical-python-for-time-series-analysis-5452014/modules') import utils

from modules import utils
df = utils.add_time_features(df)

df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 4
#       1 #import sys
#       2 #sys.path.append('C:/Users/mmart/Documents/MM Computer files/Programming/LITimeSeries/practical-python-for-time-series-analysis-5452014/modules') import utils
# ----> 4 from modules import utils
#       5 df = utils.add_time_features(df)
#       7 df
#
# File ~\Documents\MM Computer files\Programming\LITimeSeries\practical-python-for-time-series-analysis-5452014\notebooks\CH02_Groupby\modules\utils.py:9
#       7 import seaborn as sns
#       8 import statsmodels.api as sm
# ----> 9 from prophet import Prophet
#      10 from scipy.stats import norm
#      11 from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'prophet'

# %% [markdown]
# ## Steps

# %% [markdown]
# ### Aggregate data with groupby

# %%
cols_cat = ['hour', 'technology']
cols_num = 'energy'

r = df.groupby(cols_cat)[cols_num].agg(func='sum')
r
# Out:
# hour  technology
# 0     Coal           158031
#       Hydro         1694126
#                      ...
# 23    Solar            5230
#       Wind          1058245
# Name: energy, Length: 192, dtype: int64

# %% [markdown]
# ### Reset index to transform result into a data frame

# %%
r = r.reset_index()
r
# Out:
#      hour technology   energy
# 0       0       Coal   158031
# 1       0      Hydro  1694126
# ..    ...        ...      ...
# 190    23      Solar     5230
# 191    23       Wind  1058245
#
# [192 rows x 3 columns]

# %% [markdown]
# ### Bar chart

# %%
import plotly.express as px
fig = px.bar(
    data_frame=r,
    x='hour',
    y=cols_num,
    color='technology',
)

fig

# %% [markdown]
# ## Different parameters to visualize the bar chart

# %% [markdown]
# ### Aggregate by 3 categorical columns

# %%
cols_cat = ['hour', 'technology', 'month']
cols_num = 'energy'

r = df.groupby(cols_cat)[cols_num].agg(func='sum')
r = r.reset_index()
r
# Out:
#       hour technology  month  energy
# 0        0       Coal      1    7974
# 1        0       Coal      2    6698
# ...    ...        ...    ...     ...
# 2302    23       Wind     11   56956
# 2303    23       Wind     12   53996
#
# [2304 rows x 4 columns]

# %% [markdown]
# ### Plot with facets

# %% [markdown]
# #### Columns

# %%
fig = px.bar(
    data_frame=r,
    x="hour",
    y=cols_num,
    color="technology",
    facet_col="month",
    facet_col_wrap=4,
)

fig

# %% [markdown]
# #### Rows

# %%
fig = px.bar(
    data_frame=r,
    x="hour",
    y=cols_num,
    color="technology",
    facet_row="month",
    height=3000
)

fig

# %% [markdown]
# ### Aggregate by 4 categorical columns

# %%
cols_cat = ['hour', 'technology', 'month', 'weekday']
cols_num = 'energy'

r = df.groupby(cols_cat)[cols_num].agg(func='sum')
r = r.reset_index()
r
# Out:
#        hour technology  month  weekday  energy
# 0         0       Coal      1        0    1380
# 1         0       Coal      1        1    1397
# ...     ...        ...    ...      ...     ...
# 16126    23       Wind     12        5    8895
# 16127    23       Wind     12        6   12396
#
# [16128 rows x 5 columns]

# %%
fig = px.bar(
    data_frame=r,
    x="hour",
    y=cols_num,
    color="technology",
    facet_row="month",
    facet_col="weekday",
    height=3000
)

fig
